# %%
from qat.qlmaas import QLMaaSConnection
conn = QLMaaSConnection(hostname="qlm35e.neasqc.eu", check_host=False)

# %%
import parameters
from SQA_hyper_tuning_BO import BayesianOptimizer, SQA_solver, Brute_Force_Solver
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time

# %%
n_shots, delta_t = parameters.n_shots, parameters.delta_t
n_init, n_iters = parameters.n_init, parameters.n_iters
min_vals, max_vals = parameters.min_vals, parameters.max_vals
bounds = [(min_vals[i], max_vals[i]) for i in range(len(min_vals))]

# %%
n_spinss = np.array([5, 10, 15, 20])
n_repeats = 4  # Number of times to repeat the optimization with different seeds

energies = np.zeros((len(n_spinss), n_iters, n_repeats))
betas = np.zeros_like(energies)
annealing_times = np.zeros_like(energies)
gamma_0s = np.zeros_like(energies)
n_trotterss = np.zeros_like(energies)

opt_energy = np.zeros((len(n_spinss), n_repeats))
opt_betas = np.zeros((len(n_spinss), n_repeats))
opt_annealing_times = np.zeros((len(n_spinss), n_repeats))
opt_gamma_0s = np.zeros((len(n_spinss), n_repeats))
opt_n_trotterss = np.zeros((len(n_spinss), n_repeats))

times = np.zeros((len(n_spinss), n_repeats))

bf_energies = np.zeros_like(n_spinss)
bf_times = np.zeros_like(n_spinss)

for i, n_spins in enumerate(n_spinss):
    sqa = SQA_solver(n_spins=n_spins, n_shots=n_shots, delta_t=delta_t)
    # Generate a random Ising problem (same for all runs)
    J, h = sqa.generate_random_problems(n_examples=1, seed=1)
    print(f"Running BO for n_spins = {n_spins}...")
    for j in range(n_repeats):
        print(f"Repetition {j+1}/{n_repeats}")
        start = time.time()
        bo = BayesianOptimizer(sqa=sqa, bounds=bounds, n_init=n_init, seed=j+1)
        X_opt, Y_opt, history = bo.optimize(n_iters=n_iters)
        end = time.time()

        best_idx = np.argmin(Y_opt)
        opt_energy[i,j] = Y_opt[best_idx][0]
        opt_betas[i,j] = X_opt[best_idx][0]
        opt_annealing_times[i,j] = X_opt[best_idx][1]
        opt_gamma_0s[i,j] = X_opt[best_idx][2]    
        opt_n_trotterss[i,j] = int(X_opt[best_idx][3])

        energies[i,:,j] = np.array([t[1] for t in history])
        betas[i,:,j] = np.array([t[0][0] for t in history])
        annealing_times[i,:,j] = np.array([t[0][1] for t in history])
        gamma_0s[i,:,j] = np.array([t[0][2] for t in history])
        n_trotterss[i,:,j] = np.array([t[0][3] for t in history])
        times[i,j] = end -start

    bf_start = time.time()
    bf_solver = Brute_Force_Solver(J, h)
    exact_gs_energy, _ = bf_solver.brute_force_solve()
    bf_end = time.time()
    bf_energies[i] = exact_gs_energy
    bf_times[i] = bf_end - bf_start
    
print("\nSimulation completed. Taking averages and standard deviations...")
avg_energies = np.mean(energies, axis=2)
avg_betas = np.mean(betas, axis=2)
avg_annealing_times = np.mean(annealing_times, axis=2)
avg_gamma_0s = np.mean(gamma_0s, axis=2)
avg_n_trotterss = np.mean(n_trotterss, axis=2)

std_energies = np.std(energies, axis=2)
std_betas = np.std(betas, axis=2)
std_annealing_times = np.std(annealing_times, axis=2)
std_gamma_0s = np.std(gamma_0s, axis=2)
std_n_trotterss = np.std(n_trotterss, axis=2)
# Out:
# Running BO for n_spins = 5...
# Repetition 1/4
# Submitted a new batch: SJob44172
# Submitted a new batch: SJob44173
# Submitted a new batch: SJob44174
# Submitted a new batch: SJob44175
# Submitted a new batch: SJob44176
# Submitted a new batch: SJob44177
# Submitted a new batch: SJob44178
# Submitted a new batch: SJob44179
# Submitted a new batch: SJob44180
# Submitted a new batch: SJob44181
# Submitted a new batch: SJob44182
# Submitted a new batch: SJob44183
# Submitted a new batch: SJob44184
# Submitted a new batch: SJob44185
# Submitted a new batch: SJob44186
# Submitted a new batch: SJob44187
# Submitted a new batch: SJob44188
# Submitted a new batch: SJob44189
# Submitted a new batch: SJob44190
# Submitted a new batch: SJob44191
# Submitted a new batch: SJob44192
# Submitted a new batch: SJob44193
# Submitted a new batch: SJob44194
# Submitted a new batch: SJob44195
# Submitted a new batch: SJob44196
# Submitted a new batch: SJob44197
# Submitted a new batch: SJob44198
# Submitted a new batch: SJob44199
# Submitted a new batch: SJob44200
# Submitted a new batch: SJob44201
# Submitted a new batch: SJob44202
# Iter 1: x = [ 93.85512688 970.77939791 304.55479553  13.0748096 ], f(x) = -4.1657
# Submitted a new batch: SJob44203
# Iter 2: x = [  5.55849006 437.69897513 904.59242923   8.3606045 ], f(x) = -0.2448
# Submitted a new batch: SJob44204
# Iter 3: x = [ 28.3838574  142.75948449  18.87719403  13.18990845], f(x) = -4.1657
# Submitted a new batch: SJob44205
# Iter 4: x = [ 93.27381935 702.99356077  67.0785426   12.57479043], f(x) = -4.1657
# Submitted a new batch: SJob44206
# Iter 5: x = [ 25.03481347 467.95641302 904.38687951  12.87701923], f(x) = -4.1657
# Submitted a new batch: SJob44207
# Iter 6: x = [ 15.30638452 471.13157332 926.4006542   10.58167434], f(x) = 1.3220
# Submitted a new batch: SJob44208
# Iter 7: x = [ 59.93323362 821.02668251  18.92624014   5.01760865], f(x) = -4.1657
# Submitted a new batch: SJob44209
# Iter 8: x = [ 93.19993651 610.06741282  14.63653365  13.51366824], f(x) = -4.1657
# Submitted a new batch: SJob44210
# Iter 9: x = [ 15.74568389 469.73210193 876.30694982   8.89836245], f(x) = -4.1657
# Submitted a new batch: SJob44211
# Iter 10: x = [ 67.87594319 554.66345348 409.99063155   3.1014331 ], f(x) = 3.3073
# Submitted a new batch: SJob44212
# Iter 11: x = [  2.39085695 100.53532842 192.77857698  14.26115271], f(x) = -2.5733
# Submitted a new batch: SJob44213
# Iter 12: x = [ 32.25607524 593.25705527 419.17974436   1.37383318], f(x) = 3.3073
# Submitted a new batch: SJob44214
# Iter 13: x = [ 17.19978684 464.53694589 890.40038743   8.78417756], f(x) = -4.1657
# Submitted a new batch: SJob44215
# Iter 14: x = [ 37.00777135 445.55742066 902.96625737  10.29498913], f(x) = -4.1657
# Submitted a new batch: SJob44216
# Iter 15: x = [ 32.42343665 453.37191788 870.97847354   9.87881152], f(x) = -4.1657
# Submitted a new batch: SJob44217
# Iter 16: x = [ 83.48426882 958.48246624 298.83705681  13.23755597], f(x) = -4.1657
# Submitted a new batch: SJob44218
# Iter 17: x = [ 28.79940975 881.44309327  41.65362587   9.4851721 ], f(x) = -4.1657
# Submitted a new batch: SJob44219
# Iter 18: x = [ 48.4987534  445.17573843 885.66885552  14.55247784], f(x) = -4.1657
# Submitted a new batch: SJob44220
# Iter 19: x = [ 86.30234024 980.48078642 290.33812843   2.81675563], f(x) = 3.3073
# Submitted a new batch: SJob44221
# Iter 20: x = [ 70.96171149 952.79687682 311.6339298    4.14803974], f(x) = -4.1657
# Submitted a new batch: SJob44222
# Iter 21: x = [ 23.43953542 446.9995387  909.31247553   7.95724392], f(x) = -4.1657
# Submitted a new batch: SJob44223
# Iter 22: x = [ 81.54142654 604.07065749  17.60391335   1.48725968], f(x) = 3.3073
# Submitted a new batch: SJob44224
# Iter 23: x = [ 81.2507926  938.28296819 302.10405882   3.49075782], f(x) = 3.3073
# Submitted a new batch: SJob44225
# Iter 24: x = [ 42.11067479 436.64758853 888.9939844   14.71773715], f(x) = -4.1657
# Submitted a new batch: SJob44226
# Iter 25: x = [ 90.8599013  702.15234107  55.89072771  11.77405522], f(x) = -4.1657
# Submitted a new batch: SJob44227
# Iter 26: x = [ 28.76343402 468.58257035 884.9115542    1.40935953], f(x) = 3.3073
# Submitted a new batch: SJob44228
# Iter 27: x = [ 23.89586022 458.007945   898.9830244   10.06811136], f(x) = -4.1657
# Submitted a new batch: SJob44229
# Iter 28: x = [ 32.16077506 452.05933614 902.69144888  11.3427359 ], f(x) = -4.1657
# Submitted a new batch: SJob44230
# Iter 29: x = [ 17.69637057 866.10919579  35.00945165   5.63376967], f(x) = -4.1657
# Submitted a new batch: SJob44231
# Iter 30: x = [  9.64662445 450.32111285 877.50089727   1.96250742], f(x) = 3.3073
# Submitted a new batch: SJob44232
# Iter 31: x = [ 85.39659889 956.98358537 319.02107302  13.07467742], f(x) = -4.1657
# Submitted a new batch: SJob44233
# Iter 32: x = [ 97.72291359 760.93912439 287.5596757   13.42898193], f(x) = -4.1657
# Submitted a new batch: SJob44234
# Iter 33: x = [ 56.45679413 815.64860756  33.5762064    8.86440238], f(x) = -4.1657
# Submitted a new batch: SJob44235
# Iter 34: x = [ 10.96113081 460.36241281 903.18948162  13.02860378], f(x) = 0.9861
# Submitted a new batch: SJob44236
# Iter 35: x = [ 24.03174048 134.80835939  30.46796582  14.14840989], f(x) = -4.1657
# Submitted a new batch: SJob44237
# Iter 36: x = [ 92.32370454 970.07949931 315.07573274   4.03914894], f(x) = -4.1657
# Submitted a new batch: SJob44238
# Iter 37: x = [ 30.68949083 443.27108822 895.39607687   2.85927338], f(x) = 3.3073
# Submitted a new batch: SJob44239
# Iter 38: x = [  9.65241853 101.83268602 185.61444362   5.99759466], f(x) = -4.1657
# Submitted a new batch: SJob44240
# Iter 39: x = [ 88.00129696 531.69152751 699.08845017  10.18904513], f(x) = -4.1657
# Submitted a new batch: SJob44241
# Iter 40: x = [ 62.9064883  819.06088239  35.16820411  11.27468908], f(x) = -4.1657
# Submitted a new batch: SJob44242
# Iter 41: x = [ 49.37154859 148.05707649 595.04780186   8.38319324], f(x) = -4.1657
# Submitted a new batch: SJob44243
# Iter 42: x = [ 42.35859434 723.07372145  10.10351866   7.80246932], f(x) = -4.1657
# Submitted a new batch: SJob44244
# Iter 43: x = [ 44.70194849 725.93797847   3.17169078  13.44311845], f(x) = -4.1657
# Submitted a new batch: SJob44245
# Iter 44: x = [ 16.1307654  448.30635888 915.3599444    5.99562746], f(x) = -4.1657
# Submitted a new batch: SJob44246
# Iter 45: x = [ 97.79265094 747.996674   293.38488999  11.79234891], f(x) = -4.1657
# Submitted a new batch: SJob44247
# Iter 46: x = [ 60.83884736 816.56673727  30.79943147   2.07820895], f(x) = 3.3073
# Submitted a new batch: SJob44248
# Iter 47: x = [ 23.68167988 464.12384897 901.00480969   2.95280966], f(x) = 3.3073
# Submitted a new batch: SJob44249
# Iter 48: x = [ 31.28774705 131.17197212  24.05645258  14.65734896], f(x) = -4.1657
# Submitted a new batch: SJob44250
# Iter 49: x = [ 32.67105172 536.2028657  877.63724751   9.04271705], f(x) = -4.1657
# Submitted a new batch: SJob44251
# Iter 50: x = [ 61.18595586 820.93938684  10.75135529   4.34515019], f(x) = -4.1657
# Submitted a new batch: SJob44252
# Iter 51: x = [ 86.53587454 701.33298231  58.95587302  12.30166778], f(x) = -4.1657
# Submitted a new batch: SJob44253
# Iter 52: x = [ 19.2124861  441.37775974 917.10616621   4.65943885], f(x) = -4.1657
# Submitted a new batch: SJob44254
# Iter 53: x = [ 89.93459874 751.86061804 272.10969064  13.56812296], f(x) = -4.1657
# Submitted a new batch: SJob44255
# Iter 54: x = [ 39.7224919  574.54110801 407.29338799  11.46599318], f(x) = -4.1657
# Submitted a new batch: SJob44256
# Iter 55: x = [ 53.43276701 132.9926312  593.85701742   9.67889058], f(x) = -4.1657
# Submitted a new batch: SJob44257
# Iter 56: x = [ 24.18375211 454.3298203  905.29707888  11.25002306], f(x) = -4.1657
# Submitted a new batch: SJob44258
# Iter 57: x = [ 62.65616166 155.66412192 594.0972943    6.204722  ], f(x) = -4.1657
# Submitted a new batch: SJob44259
# Iter 58: x = [ 38.54072615 451.45066372 906.17684558  12.9724313 ], f(x) = -4.1657
# Submitted a new batch: SJob44260
# Iter 59: x = [ 97.22698437 699.08198987  59.78091054   1.3207685 ], f(x) = 3.3073
# Submitted a new batch: SJob44261
# Iter 60: x = [ 79.95335772 767.10472465 275.48916568   9.40907039], f(x) = -4.1657
# Repetition 2/4
# Submitted a new batch: SJob44262
# Submitted a new batch: SJob44263
# Submitted a new batch: SJob44264
# Submitted a new batch: SJob44265
# Submitted a new batch: SJob44266
# Submitted a new batch: SJob44267
# Submitted a new batch: SJob44268
# Submitted a new batch: SJob44269
# Submitted a new batch: SJob44270
# Submitted a new batch: SJob44271
# Submitted a new batch: SJob44272
# Submitted a new batch: SJob44273
# Submitted a new batch: SJob44274
# Submitted a new batch: SJob44275
# Submitted a new batch: SJob44276
# Submitted a new batch: SJob44277
# Submitted a new batch: SJob44278
# Submitted a new batch: SJob44279
# Submitted a new batch: SJob44280
# Submitted a new batch: SJob44281
# Submitted a new batch: SJob44282
# Submitted a new batch: SJob44283
# Submitted a new batch: SJob44284
# Submitted a new batch: SJob44285
# Submitted a new batch: SJob44286
# Submitted a new batch: SJob44287
# Submitted a new batch: SJob44288
# Submitted a new batch: SJob44289
# Submitted a new batch: SJob44290
# Submitted a new batch: SJob44291
# Submitted a new batch: SJob44292
# Iter 1: x = [ 80.04351387 543.70253813 227.11333284  10.57758338], f(x) = -4.1657
# Submitted a new batch: SJob44293
# Iter 2: x = [ 85.2819253  549.13784573 217.62162821   8.35655993], f(x) = -4.1657
# Submitted a new batch: SJob44294
# Iter 3: x = [ 95.46132786 492.45273934 883.8025466    9.17515484], f(x) = -4.1657
# Submitted a new batch: SJob44295
# Iter 4: x = [ 84.48411415 871.67826217  18.56723831   4.5377693 ], f(x) = -4.1657
# Submitted a new batch: SJob44296
# Iter 5: x = [ 99.50347017 494.30274602 886.43251737   4.3810844 ], f(x) = -4.1657
# Submitted a new batch: SJob44297
# Iter 6: x = [ 39.25671086  33.13767907 555.30820856  13.1953703 ], f(x) = -4.1657
# Submitted a new batch: SJob44298
# Iter 7: x = [ 22.73389982  67.57890776 996.63624822  13.39778987], f(x) = -4.1657
# Submitted a new batch: SJob44299
# Iter 8: x = [ 92.35110402 474.24132186 916.43220466   6.26151037], f(x) = -4.1657
# Submitted a new batch: SJob44300
# Iter 9: x = [ 86.18113504  42.23702233 594.80557683   5.48363379], f(x) = -4.1657
# Submitted a new batch: SJob44301
# Iter 10: x = [ 20.58716286 207.03499002 626.72296781   3.53791869], f(x) = 3.3073
# Submitted a new batch: SJob44302
# Iter 11: x = [ 83.8036723  167.76222205 556.39619779  10.8986696 ], f(x) = -4.1657
# Submitted a new batch: SJob44303
# Iter 12: x = [ 59.85104226 298.32967293 607.78857197   2.31458624], f(x) = 3.3073
# Submitted a new batch: SJob44304
# Iter 13: x = [ 86.81218945 644.69061399 194.13436547   5.52501671], f(x) = -4.1657
# Submitted a new batch: SJob44305
# Iter 14: x = [ 49.6482869  135.35840239 562.53215006  10.15711613], f(x) = -4.1657
# Submitted a new batch: SJob44306
# Iter 15: x = [ 77.61515093 472.37366065 461.80284878  10.2249389 ], f(x) = -4.1657
# Submitted a new batch: SJob44307
# Iter 16: x = [ 54.13975141  12.45499622 618.17195504  13.01662557], f(x) = -4.1657
# Submitted a new batch: SJob44308
# Iter 17: x = [ 73.78178724 150.95324477 587.46797465  13.22334117], f(x) = -4.1657
# Submitted a new batch: SJob44310
# Iter 18: x = [ 55.86540997  72.4897624  575.10365333  10.24042429], f(x) = -4.1657
# Submitted a new batch: SJob44311
# Iter 19: x = [ 55.15840918  57.04890265 628.26397626  14.31506825], f(x) = -4.1657
# Submitted a new batch: SJob44313
# Iter 20: x = [ 77.61102015 421.61933913 383.87250212   9.70657207], f(x) = -4.1657
# Submitted a new batch: SJob44314
# Iter 21: x = [  6.62791903 333.49178092 242.42602703   3.90428523], f(x) = 1.3220
# Submitted a new batch: SJob44315
# Iter 22: x = [ 71.32044029 332.09117025 198.29936721   4.13303559], f(x) = -4.1657
# Submitted a new batch: SJob44317
# Iter 23: x = [ 75.24137734 374.0763253  256.22271382   7.25576261], f(x) = -4.1657
# Submitted a new batch: SJob44318
# Iter 24: x = [ 96.8013203  342.25741296 265.07623116   8.74122758], f(x) = -4.1657
# Submitted a new batch: SJob44319
# Iter 25: x = [  8.22001712 268.06098588 632.02138505  12.36245019], f(x) = -1.8520
# Submitted a new batch: SJob44320
# Iter 26: x = [ 79.02716512 353.52103791 302.54780814  14.08953751], f(x) = -4.1657
# Submitted a new batch: SJob44321
# Iter 27: x = [ 68.31662063 442.50250575 483.83223557   5.97014451], f(x) = -4.1657
# Submitted a new batch: SJob44323
# Iter 28: x = [ 90.87487326 690.19684155 174.71367755   2.56984006], f(x) = 3.3073
# Submitted a new batch: SJob44324
# Iter 29: x = [ 79.99557194 623.3066408  174.25938439   5.0090339 ], f(x) = -4.1657
# Submitted a new batch: SJob44325
# Iter 30: x = [ 24.08887512  40.64139991 600.70888886  13.06204083], f(x) = -4.1657
# Submitted a new batch: SJob44326
# Iter 31: x = [ 93.53162713 403.37660095 325.76641489   3.48826531], f(x) = 3.3073
# Submitted a new batch: SJob44327
# Iter 32: x = [ 46.01380433 427.90507653 406.82588086  14.89909295], f(x) = -4.1657
# Submitted a new batch: SJob44328
# Iter 33: x = [ 59.50382541 628.08213304 158.61072504  12.42037879], f(x) = -4.1657
# Submitted a new batch: SJob44329
# Iter 34: x = [ 73.39998541 639.56311514 192.84592288  13.68853694], f(x) = -4.1657
# Submitted a new batch: SJob44330
# Iter 35: x = [ 55.98090668 417.97199939 377.88973152   1.90245086], f(x) = 3.3073
# Submitted a new batch: SJob44331
# Iter 36: x = [ 51.08247656  28.96454835 578.30737288   9.11256555], f(x) = -4.1657
# Submitted a new batch: SJob44332
# Iter 37: x = [ 87.32241425 449.54328001 394.11187061   4.22442214], f(x) = -4.1657
# Submitted a new batch: SJob44334
# Iter 38: x = [ 53.73627204 646.52173019 168.30049773   3.08966932], f(x) = 3.3073
# Submitted a new batch: SJob44335
# Iter 39: x = [ 62.66068022  55.8303207  589.66199126  13.30632887], f(x) = -4.1657
# Submitted a new batch: SJob44336
# Iter 40: x = [ 61.41005188  32.93238053 633.60641535  12.8552666 ], f(x) = -4.1657
# Submitted a new batch: SJob44337
# Iter 41: x = [ 88.06335283 426.33564248 416.02603951   8.62880154], f(x) = -4.1657
# Submitted a new batch: SJob44338
# Iter 42: x = [ 83.52882069 616.20904349 164.06006079  10.69247361], f(x) = -4.1657
# Submitted a new batch: SJob44339
# Iter 43: x = [ 70.78913015 428.01207351 405.71028008  11.41784929], f(x) = -4.1657
# Submitted a new batch: SJob44340
# Iter 44: x = [ 60.61445048 460.77259222 501.81230605  14.83699212], f(x) = -4.1657
# Submitted a new batch: SJob44341
# Iter 45: x = [ 60.99819905 617.52870359 155.48511198   6.81538311], f(x) = -4.1657
# Submitted a new batch: SJob44342
# Iter 46: x = [ 52.44964632  35.3782854  612.32902209   2.99429725], f(x) = 3.3073
# Submitted a new batch: SJob44343
# Iter 47: x = [ 70.09069542  42.34873417 569.16767641  10.37903307], f(x) = -4.1657
# Submitted a new batch: SJob44344
# Iter 48: x = [ 70.91604112 162.95440214 566.15803874  11.10451889], f(x) = -4.1657
# Submitted a new batch: SJob44345
# Iter 49: x = [ 85.04018619 423.91985509 404.3642115    6.77150535], f(x) = -4.1657
# Submitted a new batch: SJob44346
# Iter 50: x = [ 61.67536612   4.35748785 626.07241775  11.32567792], f(x) = -4.1657
# Submitted a new batch: SJob44347
# Iter 51: x = [ 71.67897079  69.92264087 626.10836561  13.20258753], f(x) = -4.1657
# Submitted a new batch: SJob44348
# Iter 52: x = [ 52.19525174 148.56237287 577.29728987   3.41078585], f(x) = 3.3073
# Submitted a new batch: SJob44349
# Iter 53: x = [ 72.99455802 355.92729911 270.3307871   11.94242658], f(x) = -4.1657
# Submitted a new batch: SJob44350
# Iter 54: x = [ 34.95808285 133.46905155 551.44401486  12.09694699], f(x) = -4.1657
# Submitted a new batch: SJob44351
# Iter 55: x = [ 59.41458086 433.47600957 422.49386163   9.94043792], f(x) = -4.1657
# Submitted a new batch: SJob44352
# Iter 56: x = [ 84.79286313  51.56071869 585.79154974   8.34407456], f(x) = -4.1657
# Submitted a new batch: SJob44353
# Iter 57: x = [ 41.07940607  53.9132176  566.27684655  10.48086038], f(x) = -4.1657
# Submitted a new batch: SJob44354
# Iter 58: x = [ 76.76469731 459.89693311 491.08197352  13.00508606], f(x) = -4.1657
# Submitted a new batch: SJob44355
# Iter 59: x = [ 99.95566559 436.0180235  387.55878519  11.48952797], f(x) = -4.1657
# Submitted a new batch: SJob44356
# Iter 60: x = [ 77.76272506  51.42123154 647.06728635   9.97473504], f(x) = -4.1657
# Repetition 3/4
# Submitted a new batch: SJob44357
# Submitted a new batch: SJob44358
# Submitted a new batch: SJob44359
# Submitted a new batch: SJob44360
# Submitted a new batch: SJob44361
# Submitted a new batch: SJob44362
# Submitted a new batch: SJob44363
# Submitted a new batch: SJob44364
# Submitted a new batch: SJob44365
# Submitted a new batch: SJob44366
# Submitted a new batch: SJob44367
# Submitted a new batch: SJob44368
# Submitted a new batch: SJob44369
# Submitted a new batch: SJob44370
# Submitted a new batch: SJob44371
# Submitted a new batch: SJob44372
# Submitted a new batch: SJob44373
# Submitted a new batch: SJob44374
# Submitted a new batch: SJob44375
# Submitted a new batch: SJob44376
# Submitted a new batch: SJob44377
# Submitted a new batch: SJob44378
# Submitted a new batch: SJob44379
# Submitted a new batch: SJob44380
# Submitted a new batch: SJob44381
# Submitted a new batch: SJob44382
# Submitted a new batch: SJob44383
# Submitted a new batch: SJob44384
# Submitted a new batch: SJob44385
# Submitted a new batch: SJob44386
# Submitted a new batch: SJob44387
# Iter 1: x = [ 75.69432831 288.99144186 686.22398181   4.73143541], f(x) = -4.1657
# Submitted a new batch: SJob44388
# Iter 2: x = [ 57.20671219 710.37923313 300.14514756   4.81024381], f(x) = -4.1657
# Submitted a new batch: SJob44389
# Iter 3: x = [ 43.56327208 849.05231639 586.22871439   3.16884953], f(x) = 3.3073
# Submitted a new batch: SJob44390
# Iter 4: x = [ 77.47215462 746.19066444 680.12007581  11.10074989], f(x) = -4.1657
# Submitted a new batch: SJob44391
# Iter 5: x = [ 33.75949205 939.90718264 967.15555873  11.88679244], f(x) = -4.1657
# Submitted a new batch: SJob44392
# Iter 6: x = [ 67.48413367 284.65136893 670.62257157   7.33918169], f(x) = -4.1657
# Submitted a new batch: SJob44393
# Iter 7: x = [ 45.84028206  89.65286783 478.99582997   5.27631061], f(x) = -4.1657
# Submitted a new batch: SJob44394
# Iter 8: x = [ 65.66501604 541.8220251  712.7109608    8.57699845], f(x) = -4.1657
# Submitted a new batch: SJob44395
# Iter 9: x = [ 76.13839557 546.5702496  719.55742307  14.47925283], f(x) = -4.1657
# Submitted a new batch: SJob44396
# Iter 10: x = [ 65.53281563 542.94889962 710.68580543   3.49785468], f(x) = 3.3073
# Submitted a new batch: SJob44397
# Iter 11: x = [ 59.56728423 553.39878636 362.25348433   6.47348454], f(x) = -4.1657
# Submitted a new batch: SJob44398
# Iter 12: x = [ 75.45659417 312.47153885 127.24230494   6.73552348], f(x) = -4.1657
# Submitted a new batch: SJob44399
# Iter 13: x = [ 26.65384891 187.68431442 504.94640352   9.82553261], f(x) = -4.1657
# Submitted a new batch: SJob44400
# Iter 14: x = [ 75.38783235 178.17664048  20.01192342  12.13721397], f(x) = -4.1657
# Submitted a new batch: SJob44401
# Iter 15: x = [ 38.41828079 862.2579246  581.81974657   8.81953848], f(x) = -4.1657
# Submitted a new batch: SJob44402
# Iter 16: x = [ 68.13655797 543.60646713 719.32450547   5.29316392], f(x) = -4.1657
# Submitted a new batch: SJob44403
# Iter 17: x = [ 38.41024515 672.31251627 348.49866844   7.45516085], f(x) = -4.1657
# Submitted a new batch: SJob44404
# Iter 18: x = [ 66.98506213 740.4876067  689.2593157    9.77881991], f(x) = -4.1657
# Submitted a new batch: SJob44405
# Iter 19: x = [ 83.8900309  751.80356303 657.4986657   10.04392257], f(x) = -4.1657
# Submitted a new batch: SJob44406
# Iter 20: x = [ 56.79277313 560.06051212 364.70092153  11.79975581], f(x) = -4.1657
# Submitted a new batch: SJob44407
# Iter 21: x = [ 96.26460779 842.85192846 727.22336902  11.42491636], f(x) = -4.1657
# Submitted a new batch: SJob44408
# Iter 22: x = [ 64.69447238 562.14859326 363.93583785   2.29144491], f(x) = 3.3073
# Submitted a new batch: SJob44409
# Iter 23: x = [ 58.11577774 549.5713056  360.27224717  10.65565356], f(x) = -4.1657
# Submitted a new batch: SJob44410
# Iter 24: x = [ 52.02525071 560.3110529  365.51661119  11.59288919], f(x) = -4.1657
# Submitted a new batch: SJob44411
# Iter 25: x = [ 75.24065398 747.58340483 697.0767197   12.72305275], f(x) = -4.1657
# Submitted a new batch: SJob44413
# Iter 26: x = [ 35.58990964 936.84641126 958.00541179  11.63687486], f(x) = -4.1657
# Submitted a new batch: SJob44415
# Iter 27: x = [ 74.73479947 543.2463864  722.10910764   9.97585102], f(x) = -4.1657
# Submitted a new batch: SJob44417
# Iter 28: x = [  1.81697522 954.59568342 859.08206423   2.23904819], f(x) = 3.3073
# Submitted a new batch: SJob44419
# Iter 29: x = [ 47.35747378 707.080313   290.79486257  11.52023055], f(x) = -4.1657
# Submitted a new batch: SJob44421
# Iter 30: x = [ 74.91566504 745.41155615 686.45906365  14.69561163], f(x) = -4.1657
# Submitted a new batch: SJob44422
# Iter 31: x = [ 68.36356821 545.21586392 718.07494207   7.24034656], f(x) = -4.1657
# Submitted a new batch: SJob44423
# Iter 32: x = [ 70.09984793 544.38077106 719.53517932   6.48769538], f(x) = -4.1657
# Submitted a new batch: SJob44424
# Iter 33: x = [ 47.02373411 712.97412377 292.14761254   9.6067951 ], f(x) = -4.1657
# Submitted a new batch: SJob44425
# Iter 34: x = [ 50.12641623 784.66367301 312.26799959   4.2116228 ], f(x) = -4.1657
# Submitted a new batch: SJob44426
# Iter 35: x = [ 38.33101065 675.79593971 354.21002489   4.69355621], f(x) = -4.1657
# Submitted a new batch: SJob44427
# Iter 36: x = [ 88.75735882 753.60456347 652.77428448   8.14927349], f(x) = -4.1657
# Submitted a new batch: SJob44428
# Iter 37: x = [ 73.85669005 288.33302135 690.88571024  12.40055125], f(x) = -4.1657
# Submitted a new batch: SJob44429
# Iter 38: x = [ 65.94950363 554.63431068 365.85920736   4.26340243], f(x) = -4.1657
# Submitted a new batch: SJob44430
# Iter 39: x = [ 28.22693957 679.25801061 341.7939432   11.77301703], f(x) = -4.1657
# Submitted a new batch: SJob44431
# Iter 40: x = [ 62.52965147 706.33763359 285.3861084   10.32090809], f(x) = -4.1657
# Submitted a new batch: SJob44432
# Iter 41: x = [ 67.53028135 739.37717222 678.59416612   7.19512042], f(x) = -4.1657
# Submitted a new batch: SJob44433
# Iter 42: x = [ 73.16198686 280.19280965 693.03110955   6.3639265 ], f(x) = -4.1657
# Submitted a new batch: SJob44434
# Iter 43: x = [ 29.62479377 667.68609072 354.22273482   3.19041874], f(x) = 3.3073
# Submitted a new batch: SJob44435
# Iter 44: x = [ 62.5069618  738.01430099 690.25263297   3.06797735], f(x) = 3.3073
# Submitted a new batch: SJob44436
# Iter 45: x = [ 72.01081727 545.98946998  87.00560727   8.05596554], f(x) = -4.1657
# Submitted a new batch: SJob44437
# Iter 46: x = [ 32.13937275 938.88410813 961.38411942  13.25744615], f(x) = -4.1657
# Submitted a new batch: SJob44438
# Iter 47: x = [ 70.45563845 176.43221711  23.11827177  12.45535252], f(x) = -4.1657
# Submitted a new batch: SJob44439
# Iter 48: x = [ 36.07044996 663.70419222 343.84848639  10.79774984], f(x) = -4.1657
# Submitted a new batch: SJob44440
# Iter 49: x = [ 77.57838331 739.62941724 666.83933641   7.89602161], f(x) = -4.1657
# Submitted a new batch: SJob44441
# Iter 50: x = [ 53.31765869 554.77507978 350.86484791   1.14689244], f(x) = 3.3073
# Submitted a new batch: SJob44442
# Iter 51: x = [ 50.84552123 707.63354296 286.36137871   9.87214907], f(x) = -4.1657
# Submitted a new batch: SJob44443
# Iter 52: x = [ 32.53389919 447.16990091  57.21871767  13.28996826], f(x) = -4.1657
# Submitted a new batch: SJob44444
# Iter 53: x = [ 42.24973196 874.32574578 576.68003845   6.07090205], f(x) = -4.1657
# Submitted a new batch: SJob44445
# Iter 54: x = [ 71.84404988 747.05068454 682.1372589    4.28426033], f(x) = -4.1657
# Submitted a new batch: SJob44446
# Iter 55: x = [ 70.70255368 532.28601105 721.83070935  11.2181158 ], f(x) = -4.1657
# Submitted a new batch: SJob44447
# Iter 56: x = [ 46.55100188 681.60471601 348.06682717   9.59690879], f(x) = -4.1657
# Submitted a new batch: SJob44448
# Iter 57: x = [ 93.45639869 789.68967874 488.18447399   3.42612283], f(x) = 3.3073
# Submitted a new batch: SJob44449
# Iter 58: x = [ 65.70004475 542.27145766  91.68376071   3.93190745], f(x) = 3.3073
# Submitted a new batch: SJob44450
# Iter 59: x = [ 46.2545561  883.37247644 574.20643761   9.54497552], f(x) = -4.1657
# Submitted a new batch: SJob44451
# Iter 60: x = [ 69.35409443 553.00680133 357.38420824  11.03750414], f(x) = -4.1657
# Repetition 4/4
# Submitted a new batch: SJob44452
# Submitted a new batch: SJob44453
# Submitted a new batch: SJob44454
# Submitted a new batch: SJob44455
# Submitted a new batch: SJob44456
# Submitted a new batch: SJob44457
# Submitted a new batch: SJob44458
# Submitted a new batch: SJob44459
# Submitted a new batch: SJob44460
# Submitted a new batch: SJob44461
# Submitted a new batch: SJob44462
# Submitted a new batch: SJob44463
# Submitted a new batch: SJob44464
# Submitted a new batch: SJob44465
# Submitted a new batch: SJob44466
# Submitted a new batch: SJob44467
# Submitted a new batch: SJob44468
# Submitted a new batch: SJob44469
# Submitted a new batch: SJob44470
# Submitted a new batch: SJob44471
# Submitted a new batch: SJob44472
# Submitted a new batch: SJob44473
# Submitted a new batch: SJob44474
# Submitted a new batch: SJob44475
# Submitted a new batch: SJob44476
# Submitted a new batch: SJob44477
# Submitted a new batch: SJob44478
# Submitted a new batch: SJob44479
# Submitted a new batch: SJob44480
# Submitted a new batch: SJob44481
# Submitted a new batch: SJob44482
# Iter 1: x = [ 54.19695219 123.05948886 769.26003575  14.7504286 ], f(x) = -4.1657
# Submitted a new batch: SJob44483
# Iter 2: x = [ 86.32980424 401.79825522 332.00172238   8.95584831], f(x) = -4.1657
# Submitted a new batch: SJob44484
# Iter 3: x = [ 76.1522631  657.6732983  445.60661586   9.20124418], f(x) = -4.1657
# Submitted a new batch: SJob44485
# Iter 4: x = [ 47.42660583 498.1964954  633.12172192   2.93099078], f(x) = 3.3073
# Submitted a new batch: SJob44486
# Iter 5: x = [ 66.46445543 632.37943314 427.36337871   2.77157105], f(x) = 3.3073
# Submitted a new batch: SJob44487
# Iter 6: x = [ 76.72785314 615.01521547  57.50860437   2.22983812], f(x) = 3.3073
# Submitted a new batch: SJob44488
# Iter 7: x = [ 83.18972838 408.87251767 342.76286496  11.77840133], f(x) = -4.1657
# Submitted a new batch: SJob44489
# Iter 8: x = [ 35.99833815 407.46374918 431.80490901  11.95109901], f(x) = -4.1657
# Submitted a new batch: SJob44490
# Iter 9: x = [ 47.40695346 943.59673606 801.94567023  12.9870918 ], f(x) = -4.1657
# Submitted a new batch: SJob44491
# Iter 10: x = [ 62.72273057 955.93116591 167.79126821  10.72304609], f(x) = -4.1657
# Submitted a new batch: SJob44492
# Iter 11: x = [ 94.97299307 632.8966332  102.0132534    5.51835045], f(x) = -4.1657
# Submitted a new batch: SJob44493
# Iter 12: x = [ 72.6917817  656.92333248 459.41614927   7.99062446], f(x) = -4.1657
# Submitted a new batch: SJob44494
# Iter 13: x = [ 39.39537482 643.9198862  401.86895377   9.41971948], f(x) = -4.1657
# Submitted a new batch: SJob44495
# Iter 14: x = [ 49.68474157 588.40653994  91.74677888   7.96619424], f(x) = -4.1657
# Submitted a new batch: SJob44496
# Iter 15: x = [ 32.87342271 610.95461203  80.0823868   11.85162874], f(x) = -4.1657
# Submitted a new batch: SJob44497
# Iter 16: x = [ 95.31014653 609.03154741  96.12287117  14.1195013 ], f(x) = -4.1657
# Submitted a new batch: SJob44498
# Iter 17: x = [ 84.49537643 668.90036784 455.11167027  14.94846125], f(x) = -4.1657
# Submitted a new batch: SJob44499
# Iter 18: x = [ 27.9992331  604.00937183  47.29736687   3.49394114], f(x) = 3.3073
# Submitted a new batch: SJob44500
# Iter 19: x = [ 56.48206071 940.32063477 182.04193236   6.68611935], f(x) = -4.1657
# Submitted a new batch: SJob44501
# Iter 20: x = [ 35.643568   607.27775114 101.53891051   6.63109062], f(x) = -4.1657
# Submitted a new batch: SJob44502
# Iter 21: x = [ 66.79361548 609.34809456  92.41770866  13.08321166], f(x) = -4.1657
# Submitted a new batch: SJob44503
# Iter 22: x = [ 48.69249781 974.92410013 166.28436163  11.13065725], f(x) = -4.1657
# Submitted a new batch: SJob44504
# Iter 23: x = [ 51.74734856 977.23373958 187.90532676   9.75509293], f(x) = -4.1657
# Submitted a new batch: SJob44505
# Iter 24: x = [ 53.69837231 403.01108047 582.29251193   7.24543411], f(x) = -4.1657
# Submitted a new batch: SJob44506
# Iter 25: x = [ 59.26585865 402.8859314  550.5668769    5.60783301], f(x) = -4.1657
# Submitted a new batch: SJob44507
# Iter 26: x = [ 61.18135178 664.3862892  370.47341809   2.34076435], f(x) = 3.3073
# Submitted a new batch: SJob44508
# Iter 27: x = [ 75.11550934 956.08779144 194.60330304   3.41617946], f(x) = 3.3073
# Submitted a new batch: SJob44509
# Iter 28: x = [ 27.41120602 981.84998533 178.64734038  11.23111421], f(x) = -4.1657
# Submitted a new batch: SJob44510
# Iter 29: x = [ 59.08385621 430.2744907  561.14285133  11.42884551], f(x) = -4.1657
# Submitted a new batch: SJob44511
# Iter 30: x = [ 86.50456576 419.99214888 565.31052599   5.03757996], f(x) = -4.1657
# Submitted a new batch: SJob44512
# Iter 31: x = [ 49.81406862 944.18974758 170.21683411   4.86242188], f(x) = -4.1657
# Submitted a new batch: SJob44513
# Iter 32: x = [ 59.89247663 680.66571683 457.76127053   7.72774808], f(x) = -4.1657
# Submitted a new batch: SJob44514
# Iter 33: x = [ 79.81033923 416.80570222 540.85628833  13.47382506], f(x) = -4.1657
# Submitted a new batch: SJob44515
# Iter 34: x = [ 48.85515299 923.13885079 181.71096303   6.72610145], f(x) = -4.1657
# Submitted a new batch: SJob44516
# Iter 35: x = [ 78.87767918 410.16400495 578.27630731  10.60592059], f(x) = -4.1657
# Submitted a new batch: SJob44517
# Iter 36: x = [ 44.90901097 597.00280738  74.80752576   8.0763406 ], f(x) = -4.1657
# Submitted a new batch: SJob44518
# Iter 37: x = [ 71.51541452 401.95646172 616.32358548  13.53322525], f(x) = -4.1657
# Submitted a new batch: SJob44519
# Iter 38: x = [  9.9081675  414.68013453 442.02842377   7.33107247], f(x) = 1.1017
# Submitted a new batch: SJob44520
# Iter 39: x = [ 55.94511204 393.15920431 408.01479243   6.10451563], f(x) = -4.1657
# Submitted a new batch: SJob44521
# Iter 40: x = [ 52.32549577 499.8152555  700.14181132  13.5190039 ], f(x) = -4.1657
# Submitted a new batch: SJob44522
# Iter 41: x = [ 44.91645677 427.96085229 420.55203193  13.71382952], f(x) = -4.1657
# Submitted a new batch: SJob44523
# Iter 42: x = [ 46.26592241 603.22154716  91.50654031  11.18250786], f(x) = -4.1657
# Submitted a new batch: SJob44524
# Iter 43: x = [ 49.57794614 421.83153512 401.76111158  13.44466797], f(x) = -4.1657
# Submitted a new batch: SJob44525
# Iter 44: x = [ 42.40836995 405.07417734 422.4792657    2.03066959], f(x) = 3.3073
# Submitted a new batch: SJob44526
# Iter 45: x = [ 39.0845008  964.03168584 174.37061998   9.04037301], f(x) = -4.1657
# Submitted a new batch: SJob44527
# Iter 46: x = [ 65.34799874 381.71079505 393.14751488   2.65736915], f(x) = 3.3073
# Submitted a new batch: SJob44528
# Iter 47: x = [ 76.5990808  410.25867892 563.46044199   1.21362071], f(x) = 3.3073
# Submitted a new batch: SJob44529
# Iter 48: x = [ 85.4879436  420.92401516 572.59673502  10.60949833], f(x) = -4.1657
# Submitted a new batch: SJob44530
# Iter 49: x = [ 38.8407991  980.59068331 184.43683656   4.34675999], f(x) = -4.1657
# Submitted a new batch: SJob44531
# Iter 50: x = [ 62.89159341 668.99360539 447.9292617    7.36846743], f(x) = -4.1657
# Submitted a new batch: SJob44532
# Iter 51: x = [ 59.07689938 928.67843685 169.0872516   13.08086615], f(x) = -4.1657
# Submitted a new batch: SJob44533
# Iter 52: x = [ 95.87535889 629.17698075  88.33127212   4.65239058], f(x) = -4.1657
# Submitted a new batch: SJob44534
# Iter 53: x = [ 75.62480437 406.53226179 593.67867852   9.26774108], f(x) = -4.1657
# Submitted a new batch: SJob44535
# Iter 54: x = [ 83.26908046 617.87975723 101.84790115   2.39272317], f(x) = 3.3073
# Submitted a new batch: SJob44536
# Iter 55: x = [ 64.70554968 414.95860839 588.07968376  14.5589259 ], f(x) = -4.1657
# Submitted a new batch: SJob44537
# Iter 56: x = [ 44.84683251 511.56240819 705.65781289   2.48265392], f(x) = 3.3073
# Submitted a new batch: SJob44538
# Iter 57: x = [ 64.65634615 402.51986384 611.02423959  12.70498671], f(x) = -4.1657
# Submitted a new batch: SJob44539
# Iter 58: x = [ 53.26864206 954.00795702 157.64820393   3.38180679], f(x) = 3.3073
# Submitted a new batch: SJob44540
# Iter 59: x = [ 84.89353759 663.7204038  445.95669889   3.73829581], f(x) = 3.3073
# Submitted a new batch: SJob44541
# Iter 60: x = [ 76.61505431 668.00918217 463.94231927  13.9923008 ], f(x) = -4.1657
# Running BO for n_spins = 10...
# Repetition 1/4
# Submitted a new batch: SJob44542
# Submitted a new batch: SJob44543
# Submitted a new batch: SJob44544
# Submitted a new batch: SJob44545
# Submitted a new batch: SJob44546
# Submitted a new batch: SJob44547
# Submitted a new batch: SJob44548
# Submitted a new batch: SJob44549
# Submitted a new batch: SJob44550
# Submitted a new batch: SJob44551
# Submitted a new batch: SJob44552
# Submitted a new batch: SJob44553
# Submitted a new batch: SJob44554
# Submitted a new batch: SJob44555
# Submitted a new batch: SJob44556
# Submitted a new batch: SJob44557
# Submitted a new batch: SJob44558
# Submitted a new batch: SJob44559
# Submitted a new batch: SJob44560
# Submitted a new batch: SJob44561
# Submitted a new batch: SJob44562
# Submitted a new batch: SJob44563
# Submitted a new batch: SJob44564
# Submitted a new batch: SJob44565
# Submitted a new batch: SJob44566
# Submitted a new batch: SJob44567
# Submitted a new batch: SJob44568
# Submitted a new batch: SJob44569
# Submitted a new batch: SJob44570
# Submitted a new batch: SJob44571
# Submitted a new batch: SJob44572
# Iter 1: x = [ 1.9889935  27.18477589 28.40365737  4.44695495], f(x) = -5.0327
# Submitted a new batch: SJob44573
# Iter 2: x = [  5.55849006 437.69897513 904.59242923   8.3606045 ], f(x) = -3.5956
# Submitted a new batch: SJob44574
# Iter 3: x = [ 28.3838574  142.75948449  18.87719403  13.18990845], f(x) = -3.6003
# Submitted a new batch: SJob44575
# Iter 4: x = [  9.89591239 424.71663263 700.92637878   8.10914476], f(x) = -5.0327
# Submitted a new batch: SJob44576
# Iter 5: x = [ 13.18462901 674.42073544 344.72807941   4.66782061], f(x) = 2.8115
# Submitted a new batch: SJob44577
# Iter 6: x = [ 17.21534692 800.12590576 388.47706473   3.22575923], f(x) = 2.8115
# Submitted a new batch: SJob44578
# Iter 7: x = [ 93.27046308 742.69792998 274.53627002  11.30124116], f(x) = 12.4967
# Submitted a new batch: SJob44579
# Iter 8: x = [  1.48610919 432.01077119 914.47979786   2.86819848], f(x) = -0.1200
# Submitted a new batch: SJob44580
# Iter 9: x = [ 29.01875742 128.18735309  18.75026055   1.72193542], f(x) = 12.4967
# Submitted a new batch: SJob44581
# Iter 10: x = [ 40.04168166 543.33706271 428.00389872  10.9802056 ], f(x) = -3.6003
# Submitted a new batch: SJob44582
# Iter 11: x = [ 22.04750207 901.10734747 432.18146673  13.08873665], f(x) = 2.8115
# Submitted a new batch: SJob44583
# Iter 12: x = [ 15.12844039 415.5413706  698.7468699   13.99433396], f(x) = -3.5956
# Submitted a new batch: SJob44584
# Iter 13: x = [ 55.94732668 149.14202984 596.87813151  10.79641212], f(x) = 12.4967
# Submitted a new batch: SJob44585
# Iter 14: x = [ 11.48695583 431.6923726  701.13666776  12.05109205], f(x) = -3.5956
# Submitted a new batch: SJob44586
# Iter 15: x = [ 32.6921814  536.6992337  887.62308315   4.17376283], f(x) = 2.8115
# Submitted a new batch: SJob44587
# Iter 16: x = [ 27.16872905 868.28155336  29.95549687  11.6081112 ], f(x) = 2.8115
# Submitted a new batch: SJob44588
# Iter 17: x = [ 14.06143917 415.33057927 680.45560913   1.74126209], f(x) = 12.4967
# Submitted a new batch: SJob44589
# Iter 18: x = [ 26.85275703 899.50744901 438.33354299  13.70218396], f(x) = -3.6003
# Submitted a new batch: SJob44590
# Iter 19: x = [ 45.4623937  554.95482927 432.33802916   7.91202699], f(x) = 2.8115
# Submitted a new batch: SJob44591
# Iter 20: x = [  8.88146011  78.76104426 186.34169394   1.93288123], f(x) = 12.4967
# Submitted a new batch: SJob44592
# Iter 21: x = [  7.49893106 446.66069106 906.67752644   5.69486761], f(x) = 2.8115
# Submitted a new batch: SJob44593
# Iter 22: x = [  3.03424106 414.14521083 904.71264994   8.0366936 ], f(x) = -5.0327
# Submitted a new batch: SJob44594
# Iter 23: x = [ 43.0047169  522.55029711 411.36087888  14.01743792], f(x) = -3.6003
# Submitted a new batch: SJob44595
# Iter 24: x = [ 26.90447283 893.54053842 441.30046594   3.26426571], f(x) = 12.4967
# Submitted a new batch: SJob44596
# Iter 25: x = [  7.56263858 427.65138499 706.08879162  11.7099606 ], f(x) = -4.3106
# Submitted a new batch: SJob44597
# Iter 26: x = [ 24.38344305 100.02586618 189.33182914   6.89081166], f(x) = -3.6003
# Submitted a new batch: SJob44598
# Iter 27: x = [ 25.93933407 531.01592847 667.78808483   4.21135385], f(x) = 2.8115
# Submitted a new batch: SJob44599
# Iter 28: x = [ 53.84518615 522.87542332 419.47774315  11.12977203], f(x) = -3.6003
# Submitted a new batch: SJob44600
# Iter 29: x = [ 13.8637703  420.58605571 713.94083646  12.77495972], f(x) = -7.7031
# Submitted a new batch: SJob44601
# Iter 30: x = [ 44.46112487 523.71060955 429.89048782  13.60758142], f(x) = -3.6003
# Submitted a new batch: SJob44602
# Iter 31: x = [ 51.2959805  538.13501494 410.30339574  13.86558476], f(x) = 1.3033
# Submitted a new batch: SJob44603
# Iter 32: x = [  8.91607537 426.58506582 699.58140875   1.50899379], f(x) = 12.4967
# Submitted a new batch: SJob44604
# Iter 33: x = [ 11.45649127 422.6443469  724.67145336  10.48166144], f(x) = -10.6567
# Submitted a new batch: SJob44605
# Iter 34: x = [ 61.09980653 613.10153749 115.71421893  12.47696806], f(x) = 2.8115
# Submitted a new batch: SJob44606
# Iter 35: x = [ 24.03174048 134.80835939  30.46796582  14.14840989], f(x) = 2.8115
# Submitted a new batch: SJob44607
# Iter 36: x = [ 22.04041354 105.26926675 179.74047913   7.77964503], f(x) = -3.6003
# Submitted a new batch: SJob44608
# Iter 37: x = [  8.87689517  95.91766778 188.32923629   3.66438692], f(x) = 2.8115
# Submitted a new batch: SJob44609
# Iter 38: x = [  9.65241853 101.83268602 185.61444362   5.99759466], f(x) = 2.8115
# Submitted a new batch: SJob44610
# Iter 39: x = [ 20.71998907 526.91237957 664.39171469   2.41039504], f(x) = 12.4967
# Submitted a new batch: SJob44611
# Iter 40: x = [2.51751714e-01 4.25735479e+02 6.95966821e+02 7.87265611e+00], f(x) = -1.1439
# Submitted a new batch: SJob44612
# Iter 41: x = [ 21.52259169 869.16889129  87.8491542    5.31821224], f(x) = -3.6003
# Submitted a new batch: SJob44613
# Iter 42: x = [ 42.98436485 146.71541556  19.79613234   2.99629127], f(x) = 12.4967
# Submitted a new batch: SJob44614
# Iter 43: x = [ 15.25123935 430.26828424 725.51481527  13.44399021], f(x) = -3.5956
# Submitted a new batch: SJob44615
# Iter 44: x = [ 16.1307654  448.30635888 915.3599444    5.99562746], f(x) = 2.8115
# Submitted a new batch: SJob44616
# Iter 45: x = [ 97.79265094 747.996674   293.38488999  11.79234891], f(x) = 2.8115
# Submitted a new batch: SJob44617
# Iter 46: x = [ 13.05149925 886.99272023  32.25511878  11.17463359], f(x) = -3.5956
# Submitted a new batch: SJob44618
# Iter 47: x = [ 27.99378408 878.25144455  84.58004446   7.93021065], f(x) = 2.8115
# Submitted a new batch: SJob44619
# Iter 48: x = [ 25.76545998 104.21121458 178.76401308   3.31173768], f(x) = 2.8115
# Submitted a new batch: SJob44620
# Iter 49: x = [ 32.67105172 536.2028657  877.63724751   9.04271705], f(x) = 2.8115
# Submitted a new batch: SJob44621
# Iter 50: x = [ 11.04462164 413.3630165  692.05878104   4.69242275], f(x) = 2.8115
# Submitted a new batch: SJob44622
# Iter 51: x = [ 23.25809678 421.89715736 734.79149585  10.9995796 ], f(x) = 2.8115
# Submitted a new batch: SJob44623
# Iter 52: x = [ 19.84604527 109.72807702 186.69714054   5.54938674], f(x) = 2.8115
# Submitted a new batch: SJob44624
# Iter 53: x = [ 32.02620424  99.15620558 185.66996744  12.13860009], f(x) = -7.7031
# Submitted a new batch: SJob44625
# Iter 54: x = [ 52.86807405 147.00294023 590.3695583   10.89407513], f(x) = 2.8115
# Submitted a new batch: SJob44626
# Iter 55: x = [ 37.59027189 543.88499204 876.32637297   8.35031826], f(x) = -3.6003
# Submitted a new batch: SJob44627
# Iter 56: x = [  3.86698665 904.16286382 569.65775601   2.9294298 ], f(x) = 2.8115
# Submitted a new batch: SJob44628
# Iter 57: x = [ 97.94085075 601.0502266  566.08989358   2.44175104], f(x) = 12.4967
# Submitted a new batch: SJob44629
# Iter 58: x = [ 14.22989929 894.39832018  39.2571126    1.09125893], f(x) = 12.4967
# Submitted a new batch: SJob44630
# Iter 59: x = [ 35.52218113 102.14814574 178.17610059   4.94028769], f(x) = 12.4967
# Submitted a new batch: SJob44631
# Iter 60: x = [  2.86095089 541.66018668 660.73820034   6.81599974], f(x) = -3.3633
# Repetition 2/4
# Submitted a new batch: SJob44632
# Submitted a new batch: SJob44633
# Submitted a new batch: SJob44634
# Submitted a new batch: SJob44635
# Submitted a new batch: SJob44636
# Submitted a new batch: SJob44637
# Submitted a new batch: SJob44638
# Submitted a new batch: SJob44639
# Submitted a new batch: SJob44640
# Submitted a new batch: SJob44641
# Submitted a new batch: SJob44642
# Submitted a new batch: SJob44643
# Submitted a new batch: SJob44644
# Submitted a new batch: SJob44645
# Submitted a new batch: SJob44646
# Submitted a new batch: SJob44647
# Submitted a new batch: SJob44648
# Submitted a new batch: SJob44649
# Submitted a new batch: SJob44650
# Submitted a new batch: SJob44651
# Submitted a new batch: SJob44652
# Submitted a new batch: SJob44653
# Submitted a new batch: SJob44654
# Submitted a new batch: SJob44655
# Submitted a new batch: SJob44656
# Submitted a new batch: SJob44657
# Submitted a new batch: SJob44658
# Submitted a new batch: SJob44659
# Submitted a new batch: SJob44660
# Submitted a new batch: SJob44661
# Submitted a new batch: SJob44662
# Iter 1: x = [ 80.04351387 543.70253813 227.11333284  10.57758338], f(x) = 2.8115
# Submitted a new batch: SJob44663
# Iter 2: x = [ 85.2819253  549.13784573 217.62162821   8.35655993], f(x) = 12.4967
# Submitted a new batch: SJob44664
# Iter 3: x = [ 74.00740475 541.35508849 212.33900701   4.01107532], f(x) = 12.4967
# Submitted a new batch: SJob44665
# Iter 4: x = [ 15.82807481 511.34733046 199.33971755   5.08883628], f(x) = 2.8115
# Submitted a new batch: SJob44666
# Iter 5: x = [ 89.16571253 548.24231484 236.32672389   6.27328196], f(x) = 12.4967
# Submitted a new batch: SJob44667
# Iter 6: x = [ 48.54073975 428.51063321 431.55476912   5.77572036], f(x) = 12.4967
# Submitted a new batch: SJob44668
# Iter 7: x = [ 22.73389982  67.57890776 996.63624822  13.39778987], f(x) = -7.7031
# Submitted a new batch: SJob44669
# Iter 8: x = [ 35.36287801 263.86799113 623.71655356  10.31692037], f(x) = 2.8115
# Submitted a new batch: SJob44670
# Iter 9: x = [ 34.65715858 388.09440237 830.62681691   9.10512955], f(x) = -3.6003
# Submitted a new batch: SJob44671
# Iter 10: x = [ 42.28604581 557.26319332 616.87482752   4.91088092], f(x) = 12.4967
# Submitted a new batch: SJob44672
# Iter 11: x = [ 27.1816234  378.79909247 823.21186551   7.08926083], f(x) = 2.8115
# Submitted a new batch: SJob44673
# Iter 12: x = [ 24.13093252 381.97424064 835.16746325   6.5475369 ], f(x) = -3.6003
# Submitted a new batch: SJob44674
# Iter 13: x = [ 27.65800571 394.91698964 845.16986498   5.59433268], f(x) = 2.8115
# Submitted a new batch: SJob44675
# Iter 14: x = [ 32.74864779 279.86000498 616.65230853  13.57521113], f(x) = 2.8115
# Submitted a new batch: SJob44676
# Iter 15: x = [ 27.63732425  76.82496576 991.6627432    9.63132594], f(x) = -3.6003
# Submitted a new batch: SJob44677
# Iter 16: x = [ 72.33761524 344.91978252 273.70525245   3.23219717], f(x) = 12.4967
# Submitted a new batch: SJob44678
# Iter 17: x = [ 78.35646317 650.87440149 171.40670285   7.98013022], f(x) = 12.4967
# Submitted a new batch: SJob44679
# Iter 18: x = [ 41.63704609 381.30330707 823.96161109  14.8394167 ], f(x) = -3.6003
# Submitted a new batch: SJob44680
# Iter 19: x = [ 50.44515865 359.33227393 255.18769788  10.91957418], f(x) = -3.6003
# Submitted a new batch: SJob44681
# Iter 20: x = [ 26.59076711  81.15106139 981.06560373  10.86636773], f(x) = -3.6003
# Submitted a new batch: SJob44682
# Iter 21: x = [ 31.28113252 542.87647384 605.38504812   4.82096143], f(x) = 2.8115
# Submitted a new batch: SJob44683
# Iter 22: x = [ 49.67704021 523.32781017 603.07618921   9.88262282], f(x) = 12.4967
# Submitted a new batch: SJob44684
# Iter 23: x = [ 31.01098796 514.41794478 193.99253095   8.28515397], f(x) = -3.6003
# Submitted a new batch: SJob44685
# Iter 24: x = [ 51.12752673 538.00280205 622.45953953   4.61856752], f(x) = 12.4967
# Submitted a new batch: SJob44686
# Iter 25: x = [  8.22001712 268.06098588 632.02138505  12.36245019], f(x) = -4.8213
# Submitted a new batch: SJob44687
# Iter 26: x = [ 31.21448948  66.97108729 979.86761606   2.39121284], f(x) = 12.4967
# Submitted a new batch: SJob44688
# Iter 27: x = [ 22.73691284 277.9249186  618.24084159   2.65302546], f(x) = 12.4967
# Submitted a new batch: SJob44689
# Iter 28: x = [ 25.29639564 393.55218455 833.38490463   8.22647481], f(x) = -3.6003
# Submitted a new batch: SJob44690
# Iter 29: x = [ 24.2012319  388.06990436 841.97488731  14.56788789], f(x) = -3.6003
# Submitted a new batch: SJob44691
# Iter 30: x = [ 42.12872279 526.22752795 194.99985647   8.7972929 ], f(x) = 2.8115
# Submitted a new batch: SJob44692
# Iter 31: x = [ 50.94385522 544.4429833  604.26260095   6.28298073], f(x) = 2.8115
# Submitted a new batch: SJob44693
# Iter 32: x = [ 20.57540053 520.10082599 181.28112408   7.804163  ], f(x) = 2.8115
# Submitted a new batch: SJob44694
# Iter 33: x = [ 35.88069131 538.61156139 616.43544955  11.78081196], f(x) = 2.8115
# Submitted a new batch: SJob44695
# Iter 34: x = [ 58.22958841 333.24707985 243.04157415   8.86756643], f(x) = 12.4967
# Submitted a new batch: SJob44696
# Iter 35: x = [  6.68914085 512.0587475  187.04154844   3.71481953], f(x) = 2.8115
# Submitted a new batch: SJob44697
# Iter 36: x = [ 16.66946895  72.754229   978.13692092  12.15002628], f(x) = -7.7031
# Submitted a new batch: SJob44698
# Iter 37: x = [ 49.40114204 672.49902025 162.1364546   14.45895787], f(x) = 2.8115
# Submitted a new batch: SJob44699
# Iter 38: x = [ 27.71655427 505.55692398 200.74586627   4.07810082], f(x) = 12.4967
# Submitted a new batch: SJob44700
# Iter 39: x = [ 11.06299565  60.11608485 977.16231927   9.45935409], f(x) = -7.7031
# Submitted a new batch: SJob44701
# Iter 40: x = [ 64.04961756 366.91061463 252.50777796  14.78809433], f(x) = 2.8115
# Submitted a new batch: SJob44702
# Iter 41: x = [ 24.17535684 268.99489056 621.27719367  12.2910033 ], f(x) = -7.7031
# Submitted a new batch: SJob44703
# Iter 42: x = [ 12.86529598  56.95411011 976.69604932  13.50177972], f(x) = -3.6003
# Submitted a new batch: SJob44704
# Iter 43: x = [  8.01103827  90.99515794 984.49215764   6.28737338], f(x) = -7.7031
# Submitted a new batch: SJob44705
# Iter 44: x = [  9.84322872  89.17707252 985.64669606  14.37203339], f(x) = -6.8333
# Submitted a new batch: SJob44706
# Iter 45: x = [ 25.14842307 108.3257494  984.3458709    1.64654565], f(x) = 12.4967
# Submitted a new batch: SJob44707
# Iter 46: x = [  4.83182728  74.29933783 986.97219499   9.46327925], f(x) = -5.0327
# Submitted a new batch: SJob44708
# Iter 47: x = [ 12.33550385  86.30821554 986.69090469  13.40765987], f(x) = -6.8333
# Submitted a new batch: SJob44709
# Iter 48: x = [  8.60209748  71.75966305 971.81614219  10.82256552], f(x) = -2.4588
# Submitted a new batch: SJob44710
# Iter 49: x = [ 13.93690299  59.18674875 975.88854823   7.03776506], f(x) = 2.8115
# Submitted a new batch: SJob44711
# Iter 50: x = [ 11.34912738 259.87271983 634.56407401   6.36538759], f(x) = -7.7031
# Submitted a new batch: SJob44712
# Iter 51: x = [ 12.79233718  66.49782429 984.06298563   9.95220386], f(x) = -3.6003
# Submitted a new batch: SJob44713
# Iter 52: x = [ 28.03010536  89.656679   996.7040371    4.32797164], f(x) = 12.4967
# Submitted a new batch: SJob44714
# Iter 53: x = [  2.21690932  88.94034941 997.88946458   8.9538286 ], f(x) = -8.7387
# Submitted a new batch: SJob44715
# Iter 54: x = [ 23.73842175 267.70037933 627.94370609   1.92824328], f(x) = 12.4967
# Submitted a new batch: SJob44716
# Iter 55: x = [ 70.06658559 424.5977257  445.53087762  13.30829598], f(x) = 12.4967
# Submitted a new batch: SJob44717
# Iter 56: x = [ 28.69479643 373.34831917 834.6829638    7.56260334], f(x) = 2.8115
# Submitted a new batch: SJob44718
# Iter 57: x = [ 23.40355395 519.73373766 195.28050735   9.79944104], f(x) = 2.8115
# Submitted a new batch: SJob44719
# Iter 58: x = [ 39.67838777 373.87841707 262.60246218   9.12837279], f(x) = 2.8115
# Submitted a new batch: SJob44720
# Iter 59: x = [ 39.31266812 505.58781517 178.29569585  11.66891346], f(x) = 2.8115
# Submitted a new batch: SJob44721
# Iter 60: x = [ 20.4978067  399.45019526 823.80510704   9.16906511], f(x) = -3.6003
# Repetition 3/4
# Submitted a new batch: SJob44722
# Submitted a new batch: SJob44723
# Submitted a new batch: SJob44724
# Submitted a new batch: SJob44725
# Submitted a new batch: SJob44726
# Submitted a new batch: SJob44727
# Submitted a new batch: SJob44728
# Submitted a new batch: SJob44729
# ...
# Submitted a new batch: SJob45444
# Submitted a new batch: SJob45445
# Submitted a new batch: SJob45446
# Submitted a new batch: SJob45447
# Submitted a new batch: SJob45448
# Submitted a new batch: SJob45449
# Submitted a new batch: SJob45450
# Submitted a new batch: SJob45451
# Submitted a new batch: SJob45452
# Submitted a new batch: SJob45453
# Submitted a new batch: SJob45454
# Submitted a new batch: SJob45455
# Submitted a new batch: SJob45456
# Submitted a new batch: SJob45457
# Submitted a new batch: SJob45458
# Submitted a new batch: SJob45459
# Submitted a new batch: SJob45460
# Submitted a new batch: SJob45461
# Submitted a new batch: SJob45462
# Submitted a new batch: SJob45463
# Submitted a new batch: SJob45464
# Submitted a new batch: SJob45465
# Submitted a new batch: SJob45466
# Submitted a new batch: SJob45467
# Submitted a new batch: SJob45468
# Submitted a new batch: SJob45469
# Submitted a new batch: SJob45470
# Submitted a new batch: SJob45471
# Submitted a new batch: SJob45472
# Iter 1: x = [ 34.05775687 169.06656466  74.53498133  11.01414306], f(x) = -9.2859
# Submitted a new batch: SJob45473
# Iter 2: x = [ 57.20671219 710.37923313 300.14514756   4.81024381], f(x) = -12.0973
# Submitted a new batch: SJob45474
# Iter 3: x = [ 43.56327208 849.05231639 586.22871439   3.16884953], f(x) = 30.0337
# Submitted a new batch: SJob45475
# Iter 4: x = [ 77.47215462 746.19066444 680.12007581  11.10074989], f(x) = -12.0973
# Submitted a new batch: SJob45476
# Iter 5: x = [ 33.75949205 939.90718264 967.15555873  11.88679244], f(x) = -9.2859
# Submitted a new batch: SJob45477
# Iter 6: x = [ 67.48413367 284.65136893 670.62257157   7.33918169], f(x) = -12.0973
# Submitted a new batch: SJob45478
# Iter 7: x = [ 45.84028206  89.65286783 478.99582997   5.27631061], f(x) = -12.0973
# Submitted a new batch: SJob45479
# Iter 8: x = [ 65.66501604 541.8220251  712.7109608    8.57699845], f(x) = -12.0973
# Submitted a new batch: SJob45480
# Iter 9: x = [  5.83399919 727.84080634 788.16549615  14.72121087], f(x) = -1.1896
# Submitted a new batch: SJob45481
# Iter 10: x = [ 65.53281563 542.94889962 710.68580543   3.49785468], f(x) = 30.0337
# Submitted a new batch: SJob45482
# Iter 11: x = [ 59.56728423 553.39878636 362.25348433   6.47348454], f(x) = -12.0973
# Submitted a new batch: SJob45483
# Iter 12: x = [ 75.45659417 312.47153885 127.24230494   6.73552348], f(x) = -12.0973
# Submitted a new batch: SJob45484
# Iter 13: x = [ 20.32547669 722.26594346 780.4099833   11.47840657], f(x) = -9.2859
# Submitted a new batch: SJob45485
# Iter 14: x = [ 75.38783235 178.17664048  20.01192342  12.13721397], f(x) = -12.0973
# Submitted a new batch: SJob45486
# Iter 15: x = [ 15.12938732 718.14160621 784.42620883  13.51237114], f(x) = -17.9945
# Submitted a new batch: SJob45487
# Iter 16: x = [ 68.13655797 543.60646713 719.32450547   5.29316392], f(x) = -12.0973
# Submitted a new batch: SJob45488
# Iter 17: x = [ 38.41024515 672.31251627 348.49866844   7.45516085], f(x) = -11.7908
# Submitted a new batch: SJob45489
# Iter 18: x = [ 66.98506213 740.4876067  689.2593157    9.77881991], f(x) = -12.0973
# Submitted a new batch: SJob45490
# Iter 19: x = [ 83.8900309  751.80356303 657.4986657   10.04392257], f(x) = -12.0973
# Submitted a new batch: SJob45491
# Iter 20: x = [ 56.79277313 560.06051212 364.70092153  11.79975581], f(x) = -9.2859
# Submitted a new batch: SJob45492
# Iter 21: x = [ 96.26460779 842.85192846 727.22336902  11.42491636], f(x) = -12.0973
# Submitted a new batch: SJob45493
# Iter 22: x = [ 64.69447238 562.14859326 363.93583785   2.29144491], f(x) = 30.0337
# Submitted a new batch: SJob45494
# Iter 23: x = [ 58.11577774 549.5713056  360.27224717  10.65565356], f(x) = -12.0973
# Submitted a new batch: SJob45495
# Iter 24: x = [ 52.02525071 560.3110529  365.51661119  11.59288919], f(x) = -9.2859
# Submitted a new batch: SJob45496
# Iter 25: x = [ 75.24065398 747.58340483 697.0767197   12.72305275], f(x) = -12.0973
# Submitted a new batch: SJob45497
# Iter 26: x = [ 35.58990964 936.84641126 958.00541179  11.63687486], f(x) = -9.2859
# Submitted a new batch: SJob45498
# Iter 27: x = [ 82.56343304 546.01662819  95.26478218   4.34034906], f(x) = -12.0973
# Submitted a new batch: SJob45499
# Iter 28: x = [  1.81697522 954.59568342 859.08206423   2.23904819], f(x) = -1.1902
# Submitted a new batch: SJob45500
# Iter 29: x = [ 47.35747378 707.080313   290.79486257  11.52023055], f(x) = -9.2859
# Submitted a new batch: SJob45501
# Iter 30: x = [ 74.91566504 745.41155615 686.45906365  14.69561163], f(x) = -9.2859
# Submitted a new batch: SJob45502
# Iter 31: x = [ 68.36356821 545.21586392 718.07494207   7.24034656], f(x) = -12.0973
# Submitted a new batch: SJob45503
# Iter 32: x = [ 70.09984793 544.38077106 719.53517932   6.48769538], f(x) = -12.0973
# Submitted a new batch: SJob45504
# Iter 33: x = [ 47.02373411 712.97412377 292.14761254   9.6067951 ], f(x) = -9.2859
# Submitted a new batch: SJob45505
# Iter 34: x = [ 50.12641623 784.66367301 312.26799959   4.2116228 ], f(x) = -12.0973
# Submitted a new batch: SJob45506
# Iter 35: x = [ 38.33101065 675.79593971 354.21002489   4.69355621], f(x) = -12.0973
# Submitted a new batch: SJob45507
# Iter 36: x = [ 88.75735882 753.60456347 652.77428448   8.14927349], f(x) = -12.0973
# Submitted a new batch: SJob45508
# Iter 37: x = [  8.40935667 560.5493882  264.9795861    7.40204185], f(x) = -12.6974
# Submitted a new batch: SJob45509
# Iter 38: x = [ 18.38943962 173.58451656  72.17813997  13.32196774], f(x) = -12.0973
# Submitted a new batch: SJob45510
# Iter 39: x = [ 28.22693957 679.25801061 341.7939432   11.77301703], f(x) = -11.3998
# Submitted a new batch: SJob45511
# Iter 40: x = [ 62.52965147 706.33763359 285.3861084   10.32090809], f(x) = -12.0973
# Submitted a new batch: SJob45512
# Iter 41: x = [ 67.53028135 739.37717222 678.59416612   7.19512042], f(x) = -12.0973
# Submitted a new batch: SJob45513
# Iter 42: x = [ 74.27307372 551.78866723  90.99219295   6.49632105], f(x) = -12.0973
# Submitted a new batch: SJob45514
# Iter 43: x = [ 29.62479377 667.68609072 354.22273482   3.19041874], f(x) = 30.9925
# Submitted a new batch: SJob45515
# Iter 44: x = [ 62.5069618  738.01430099 690.25263297   3.06797735], f(x) = 30.0337
# Submitted a new batch: SJob45516
# Iter 45: x = [ 72.01081727 545.98946998  87.00560727   8.05596554], f(x) = -12.0973
# Submitted a new batch: SJob45517
# Iter 46: x = [ 32.13937275 938.88410813 961.38411942  13.25744615], f(x) = -11.3998
# Submitted a new batch: SJob45518
# Iter 47: x = [ 70.45563845 176.43221711  23.11827177  12.45535252], f(x) = -12.0973
# Submitted a new batch: SJob45519
# Iter 48: x = [ 36.07044996 663.70419222 343.84848639  10.79774984], f(x) = -9.2859
# Submitted a new batch: SJob45520
# Iter 49: x = [ 77.57838331 739.62941724 666.83933641   7.89602161], f(x) = -12.0973
# Submitted a new batch: SJob45521
# Iter 50: x = [ 53.31765869 554.77507978 350.86484791   1.14689244], f(x) = 25.6189
# Submitted a new batch: SJob45522
# Iter 51: x = [ 50.84552123 707.63354296 286.36137871   9.87214907], f(x) = -9.2859
# Submitted a new batch: SJob45523
# Iter 52: x = [ 22.91374843 183.78964661  68.45082868  11.34259572], f(x) = -11.3998
# Submitted a new batch: SJob45524
# Iter 53: x = [ 25.71082089 724.92828911 782.88894937   6.87242956], f(x) = -9.2859
# Submitted a new batch: SJob45525
# Iter 54: x = [ 71.84404988 747.05068454 682.1372589    4.28426033], f(x) = -12.0973
# Submitted a new batch: SJob45526
# Iter 55: x = [ 68.21404378 710.00898545 301.57320569   3.44422063], f(x) = 30.0337
# Submitted a new batch: SJob45527
# Iter 56: x = [ 46.55100188 681.60471601 348.06682717   9.59690879], f(x) = -9.2859
# Submitted a new batch: SJob45528
# Iter 57: x = [ 93.45639869 789.68967874 488.18447399   3.42612283], f(x) = 30.0337
# Submitted a new batch: SJob45529
# Iter 58: x = [ 65.70004475 542.27145766  91.68376071   3.93190745], f(x) = 30.0337
# Submitted a new batch: SJob45530
# Iter 59: x = [ 56.95571338 561.33477217 361.44348288   5.50686988], f(x) = -12.0973
# Submitted a new batch: SJob45531
# Iter 60: x = [ 18.36640534 185.01718035  73.0986517   12.56168359], f(x) = -11.3998
# Repetition 4/4
# Submitted a new batch: SJob45532
# Submitted a new batch: SJob45533
# Submitted a new batch: SJob45534
# Submitted a new batch: SJob45535
# Submitted a new batch: SJob45536
# Submitted a new batch: SJob45537
# Submitted a new batch: SJob45538
# Submitted a new batch: SJob45539
# Submitted a new batch: SJob45540
# Submitted a new batch: SJob45541
# Submitted a new batch: SJob45542
# Submitted a new batch: SJob45543
# Submitted a new batch: SJob45544
# Submitted a new batch: SJob45545
# Submitted a new batch: SJob45546
# Submitted a new batch: SJob45547
# Submitted a new batch: SJob45548
# Submitted a new batch: SJob45549
# Submitted a new batch: SJob45550
# Submitted a new batch: SJob45551
# Submitted a new batch: SJob45552
# Submitted a new batch: SJob45553
# Submitted a new batch: SJob45554
# Submitted a new batch: SJob45555
# Submitted a new batch: SJob45556
# Submitted a new batch: SJob45557
# Submitted a new batch: SJob45558
# Submitted a new batch: SJob45559
# Submitted a new batch: SJob45560
# Submitted a new batch: SJob45561
# Submitted a new batch: SJob45562
# Iter 1: x = [ 54.19695219 123.05948886 769.26003575  14.7504286 ], f(x) = -9.2859
# Submitted a new batch: SJob45563
# Iter 2: x = [ 86.32980424 401.79825522 332.00172238   8.95584831], f(x) = -12.0973
# Submitted a new batch: SJob45564
# Iter 3: x = [ 28.6545701  156.07160512 712.57584043   6.07530467], f(x) = -9.2859
# Submitted a new batch: SJob45565
# Iter 4: x = [ 47.42660583 498.1964954  633.12172192   2.93099078], f(x) = 30.0337
# Submitted a new batch: SJob45566
# Iter 5: x = [ 31.66507729 579.51882422 373.17856028   6.23322987], f(x) = -9.2859
# Submitted a new batch: SJob45567
# Iter 6: x = [ 59.50513158 595.84973647 937.65684524  14.90672226], f(x) = -9.2859
# Submitted a new batch: SJob45568
# Iter 7: x = [ 75.76300005 412.79812038 395.19970501  10.44565583], f(x) = -12.0973
# Submitted a new batch: SJob45569
# Iter 8: x = [ 17.60470296 637.02622837 334.31313805   1.32229529], f(x) = 30.0337
# Submitted a new batch: SJob45570
# Iter 9: x = [ 23.98698588 607.21961017 393.35123523   5.63703142], f(x) = -11.7908
# Submitted a new batch: SJob45571
# Iter 10: x = [ 50.43523788 438.44137809 369.81097395   8.81889455], f(x) = -12.0973
# Submitted a new batch: SJob45572
# Iter 11: x = [ 46.32180687 103.86621203 732.99350593   8.35407726], f(x) = -12.0973
# Submitted a new batch: SJob45573
# Iter 12: x = [ 57.78373329 628.79097383 105.57627092  12.94877072], f(x) = -11.3998
# Submitted a new batch: SJob45574
# Iter 13: x = [ 31.03766621 407.05830274 361.69824643   5.93195195], f(x) = -12.0973
# Submitted a new batch: SJob45575
# Iter 14: x = [ 11.98304279 608.21287109 374.18949937   9.70079737], f(x) = -16.7440
# Submitted a new batch: SJob45576
# Iter 15: x = [ 38.53997116 378.21182969 573.59669816  14.94352081], f(x) = -9.2859
# Submitted a new batch: SJob45577
# Iter 16: x = [ 26.91077786 515.26626168 717.7982117    7.7871446 ], f(x) = -9.2859
# Submitted a new batch: SJob45578
# Iter 17: x = [ 79.18944383 585.90430078  90.65415673   4.14104422], f(x) = -12.0973
# Submitted a new batch: SJob45579
# Iter 18: x = [ 77.27094894 536.04625354 924.05772478   2.07200118], f(x) = 30.0337
# Submitted a new batch: SJob45580
# Iter 19: x = [ 62.54226977 660.88972638 925.66957498   7.02568378], f(x) = -12.0973
# Submitted a new batch: SJob45581
# Iter 20: x = [ 99.39266156 604.02938916 956.77691071   1.69376529], f(x) = 25.6189
# Submitted a new batch: SJob45582
# Iter 21: x = [ 44.97895406 618.65471636 924.82594667   2.79373002], f(x) = 30.0337
# Submitted a new batch: SJob45583
# Iter 22: x = [ 62.570054   604.6393938   87.54235166   2.22136636], f(x) = 30.0337
# Submitted a new batch: SJob45584
# Iter 23: x = [ 50.35129875 114.11682027 752.24274184   6.24978402], f(x) = -12.0973
# Submitted a new batch: SJob45585
# Iter 24: x = [ 46.19666569 602.34188114  54.43615421   9.43761372], f(x) = -9.2859
# Submitted a new batch: SJob45586
# Iter 25: x = [ 45.36630221 406.28851917 387.02938784   7.96036841], f(x) = -12.0973
# Submitted a new batch: SJob45587
# Iter 26: x = [ 84.79047936 569.87435382 100.57051734  14.97912418], f(x) = -12.0973
# Submitted a new batch: SJob45588
# Iter 27: x = [ 52.32986386 426.49052811 399.29892043   2.40329926], f(x) = 30.0337
# Submitted a new batch: SJob45589
# Iter 28: x = [ 17.81075541 619.18605834 379.60687665  13.2943618 ], f(x) = -17.8360
# Submitted a new batch: SJob45590
# Iter 29: x = [ 42.49322897 436.32790855 361.25670732   3.95226388], f(x) = 30.0337
# Submitted a new batch: SJob45591
# Iter 30: x = [ 54.06805814 123.435105   744.04556396   6.17830289], f(x) = -12.0973
# Submitted a new batch: SJob45592
# Iter 31: x = [ 15.21422594 608.12303977 354.48789121   9.8812392 ], f(x) = -14.4335
# Submitted a new batch: SJob45593
# Iter 32: x = [ 49.65507227 502.95454718 684.04334035   8.8935363 ], f(x) = -12.0973
# Submitted a new batch: SJob45594
# Iter 33: x = [ 19.59519151 400.88600455 372.07863235  12.37358396], f(x) = -11.3998
# Submitted a new batch: SJob45595
# Iter 34: x = [ 10.67940767 608.55760482 362.5767988    8.19645658], f(x) = -12.0973
# Submitted a new batch: SJob45596
# Iter 35: x = [ 93.12264315 577.7424597  102.13471255  12.67194308], f(x) = -12.0973
# Submitted a new batch: SJob45597
# Iter 36: x = [ 81.84995669 568.81777218 117.32716081   4.88931065], f(x) = -12.0973
# Submitted a new batch: SJob45598
# Iter 37: x = [ 40.66117472 611.54185471 390.54085593  14.91095949], f(x) = -11.3998
# Submitted a new batch: SJob45599
# Iter 38: x = [ 10.09296199 597.75516981 389.13451069   2.51144641], f(x) = 30.9925
# Submitted a new batch: SJob45600
# Iter 39: x = [ 31.50025312 414.01713837 378.39039928  14.18880555], f(x) = -11.3998
# Submitted a new batch: SJob45601
# Iter 40: x = [ 80.31445322 573.91472177  81.30155598  10.11938409], f(x) = -12.0973
# Submitted a new batch: SJob45602
# Iter 41: x = [ 37.75878089 622.13130684 367.32750965   6.12794081], f(x) = -12.0973
# Submitted a new batch: SJob45603
# Iter 42: x = [ 93.87681296 575.26047831  79.7420797    8.60590185], f(x) = -12.0973
# Submitted a new batch: SJob45604
# Iter 43: x = [ 77.74396468 565.06418251  93.50765672   4.48535203], f(x) = -6.5396
# Submitted a new batch: SJob45605
# Iter 44: x = [ 56.19924691 432.59558292 371.96072258  10.5801227 ], f(x) = -9.2859
# Submitted a new batch: SJob45606
# Iter 45: x = [ 43.99970748 592.79818329 367.52766261   8.20352771], f(x) = -9.2859
# Submitted a new batch: SJob45607
# Iter 46: x = [ 33.09179458 630.31598538 385.29103746   3.58873892], f(x) = 30.9925
# Submitted a new batch: SJob45608
# Iter 47: x = [ 50.8308331  126.83649569 754.47763508  10.90501715], f(x) = -12.0973
# Submitted a new batch: SJob45609
# Iter 48: x = [ 40.10423879 604.06426704 350.47915359  10.18818114], f(x) = -9.2859
# Submitted a new batch: SJob45610
# Iter 49: x = [ 18.22849518 601.8552907  363.38733397  12.93835586], f(x) = -11.3998
# Submitted a new batch: SJob45611
# Iter 50: x = [ 31.27192647 394.7276002  383.03553572   5.39593366], f(x) = -12.0973
# Submitted a new batch: SJob45612
# Iter 51: x = [ 64.87163967 445.99591825 379.65732259   9.22650878], f(x) = -12.0973
# Submitted a new batch: SJob45613
# Iter 52: x = [ 49.18759389 445.07969334 379.07477883  14.31155978], f(x) = -9.2859
# Submitted a new batch: SJob45614
# Iter 53: x = [ 63.590016   113.23345935 749.05818402   8.9723887 ], f(x) = -12.0973
# Submitted a new batch: SJob45615
# Iter 54: x = [ 52.23194764 391.59383175 384.22662714   6.36405635], f(x) = -12.0973
# Submitted a new batch: SJob45616
# Iter 55: x = [ 34.74984073 605.11441711 359.24305247   5.41532959], f(x) = -12.0973
# Submitted a new batch: SJob45617
# Iter 56: x = [ 50.64960687 611.52972787 370.14676634  14.82258788], f(x) = -9.2859
# Submitted a new batch: SJob45618
# Iter 57: x = [ 75.89664059 391.3719453  383.2682748    4.21948427], f(x) = -12.0973
# Submitted a new batch: SJob45619
# Iter 58: x = [ 63.34501392 404.73751877 367.30702565   8.82713284], f(x) = -12.0973
# Submitted a new batch: SJob45620
# Iter 59: x = [ 81.2608762  398.19314202 395.22201399   4.72552534], f(x) = -12.0973
# Submitted a new batch: SJob45621
# Iter 60: x = [ 65.4623401  636.53133368 891.80044014   2.83538696], f(x) = 30.0337
#
# Simulation completed. Taking averages and standard deviations...

# %%
# Plot energies
colors = ['blue', 'red', 'black', 'green', 'orange']
plt.figure()
for i, n_spins in enumerate(n_spinss):
    plt.errorbar(range(n_iters), avg_energies[i,:], std_energies[i,:], fmt='o', color = colors[i], capsize=5, label=f'n_spins = {n_spins}')
    plt.plot(range(n_iters), np.array([bf_energies[i]]*n_iters), '--', color = colors[i], label=f'Exact g.s. energy for {n_spins} spins')
plt.xlabel('BO iteration')
plt.ylabel('Energy')
plt.title('SQA estimated ground state energy through BO')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Plot betas
colors = ['blue', 'red', 'black', 'green', 'orange']
plt.figure()
for i, n_spins in enumerate(n_spinss):
    plt.errorbar(range(n_iters), avg_betas[i,:], std_betas[i,:], fmt='o', color = colors[i], capsize=5, label=f'n_spins = {n_spins}')
plt.xlabel('BO iteration')
plt.ylabel('Beta')
plt.title('Evolution of beta through BO')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Plot annealing_times
colors = ['blue', 'red', 'black', 'green', 'orange']
plt.figure()
for i, n_spins in enumerate(n_spinss):
    plt.errorbar(range(n_iters), avg_annealing_times[i,:], std_annealing_times[i,:], fmt='o', color = colors[i], capsize=5, label=f'n_spins = {n_spins}')
plt.xlabel('BO iteration')
plt.ylabel('Annealing time')
plt.title('Evolution of annealing_time through BO')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Plot gamma_0s
colors = ['blue', 'red', 'black', 'green', 'orange']
plt.figure()
for i, n_spins in enumerate(n_spinss):
    plt.errorbar(range(n_iters), avg_gamma_0s[i,:], std_gamma_0s[i,:], fmt='o', color = colors[i], capsize=5, label=f'n_spins = {n_spins}')
plt.xlabel('BO iteration')
plt.ylabel('Gamma_0')
plt.title('Evolution of gamma_0 through BO')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Plot n_trotterss
colors = ['blue', 'red', 'black', 'green', 'orange']
plt.figure()
for i, n_spins in enumerate(n_spinss):
    plt.errorbar(range(n_iters), avg_n_trotterss[i,:], std_n_trotterss[i,:], fmt='o', color = colors[i], capsize=5, label=f'n_spins = {n_spins}')
plt.xlabel('BO iteration')
plt.ylabel('n_trotters')
plt.title('Evolution of n_trotters through BO')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Select first repetition instead of average

# %%
# Plot energies
colors = ['blue', 'red', 'black', 'green', 'orange']
n_spinss = [5, 10, 15, 20]
n_spins_represented = 15
plt.figure()
for i, n_spins in enumerate(n_spinss):
    if n_spins == n_spins_represented:
        plt.plot(range(n_iters), energies[i,:,3],'.-', color = colors[i], label=f'n_spins = {n_spins}')
        plt.plot(range(n_iters), np.array([bf_energies[i]]*n_iters), '--', color = colors[i], label=f'Exact g.s. energy for {n_spins} spins')
        break
plt.xlabel('BO iteration')
plt.ylabel('Energy')
plt.title('SQA estimated ground state energy through BO')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Plot betas
colors = ['blue', 'red', 'black', 'green', 'orange']
n_spins_represented = 20
plt.figure()
for i, n_spins in enumerate(n_spinss):
    if n_spins == n_spins_represented:
        energies_opt = energies[i,:,0]
        indices = np.where(energies_opt < -13.5)[0]
        plt.plot(indices, betas[i,indices,0], '.-', color = colors[i], label=f'n_spins = {n_spins}')
        plt.plot(indices, energies_opt[indices],'.-', color = 'orange', label=f'n_spins = {n_spins} (Energy)')
        break
plt.xlabel('BO iteration')
plt.ylabel('Beta')
plt.title('Evolution of beta through BO')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

corr_energy_beta = np.corrcoef(betas[3,:,3], energies[3,:,3])[0, 1]
print("Correlation of energy and beta = ", corr_energy_beta)
print(bf_energies[3])
# Out:
# Correlation of energy and beta =  -0.001655753174447939
# -38

# %%
# Plot annealing_times
colors = ['blue', 'red', 'black', 'green', 'orange']
n_spins_represented = 20
plt.figure()
for i, n_spins in enumerate(n_spinss):
    if n_spins == n_spins_represented:
        energies_opt = energies[i,:,0]
        indices = np.where(energies_opt < -13.5)[0]
        plt.plot(indices, annealing_times[i,indices,0], '.-', color = colors[i], label=f'n_spins = {n_spins}')
        plt.plot(indices, energies_opt[indices],'.-', color = 'orange', label=f'n_spins = {n_spins} (Energy)')
        break
plt.xlabel('BO iteration')
plt.ylabel('Annealing_time')
plt.title('Evolution of annealing_time through BO')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

corr_energy_beta = np.corrcoef(annealing_times[3,:,2], energies[3,:,2])[0, 1]
print("Correlation of energy and beta = ", corr_energy_beta)
# Out:
# Correlation of energy and beta =  0.13791568257195266

# %%
# Plot gamma_0s
colors = ['blue', 'red', 'black', 'green', 'orange']
n_spins_represented = 20
plt.figure()
for i, n_spins in enumerate(n_spinss):
    if n_spins_represented == n_spins:
        energies_opt = energies[i,:,0]
        indices = np.where(energies_opt < -12)[0]
        plt.plot(indices, gamma_0s[i,indices,0], '.-', color = colors[i], label=f'n_spins = {n_spins}')
        plt.plot(indices, energies_opt[indices],'.-', color = 'orange', label=f'n_spins = {n_spins} (Energy)')
        break
plt.xlabel('BO iteration')
plt.ylabel('Gamma_0')
plt.title('Evolution of gamma_0 through BO')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

corr_energy_beta = np.corrcoef(gamma_0s[3,:,2], energies[3,:,2])[0, 1]
print("Correlation of energy and beta = ", corr_energy_beta)
# Out:
# Correlation of energy and beta =  -0.014434865636966538

# %%
# Plot n_trotterss
colors = ['blue', 'red', 'black', 'green', 'orange']
n_spins_represented = 20
plt.figure()
for i, n_spins in enumerate(n_spinss):
    if n_spins == n_spins_represented:
        energies_opt = energies[i,:,0]
        indices = np.where(energies_opt < -13.5)[0]
        
        plt.plot(indices, n_trotterss[i,indices,0], '.-', color = colors[i], label=f'n_spins = {n_spins}')
        plt.plot(indices, energies_opt[indices],'.-', color = 'orange', label=f'n_spins = {n_spins} (Energy)')
        break
plt.xlabel('BO iteration')
plt.ylabel('n_trotters')
plt.title('Evolution of n_trotters through BO')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

corr_energy_n_totters = np.corrcoef(n_trotterss[3,:,0], energies[3,:,0])[0, 1]
print("Correlation of energy and beta = ", corr_energy_n_totters)
print(indices)
# Out:
# Correlation of energy and beta =  -0.7493964649342071
# [ 5 18 28]
